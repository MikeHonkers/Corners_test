# %%
from IPython.display import Image, display

# %%
listOfImageNames = ['plots/diff_max.png', 'plots/diff_mean.png', 'plots/diff_min.png', 'plots/gt_corners_hist.png', 'plots/gt_vs_rb_corners.png', 'plots/max_hist.png', 'plots/max_vs_min_corners.png', 'plots/mean_hist.png', 'plots/mean_vs_max_corners.png', 'plots/min_hist.png','plots/rb_corners_hist.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
